# %%
from typing import List, Tuple

import pandas as pd
from scipy.stats import pearsonr

# train_filename = "../data/v1/sample_application_train.csv"
train_filename = "../data/v1/application_train.csv"
test_filename = "../data/v1/application_test.csv"

y_column_name = "TARGET"
sk_id_column_name = "SK_ID_CURR"

def convert_to_numeric(data: pd.DataFrame) -> pd.DataFrame:
    # not the best way to handle null values
    x_raw = data.fillna(value=0, axis=1)

    object_x = x_raw.select_dtypes(include=["object"]).copy()

    for col in object_x.columns:
        # brute force and generic way to handle categorical columns
        object_x[col + "cat"] = object_x[col].astype("category").cat.codes

    object_cat_x = object_x[
        [col for col in object_x.columns if col.endswith("cat")]]

    numeric_x = x_raw.select_dtypes(include=["float", "int"]).copy()

    return pd.concat([numeric_x, object_cat_x], axis=1)

# %%
train_data = convert_to_numeric(pd.read_csv(train_filename))

column_names = train_data.columns[2:]
target = "TARGET"


corelations = {}
for f in column_names:
    data_temp = train_data[[f, target]]
    x1 = data_temp[f].values
    x2 = data_temp[target].values
    key = f + ' vs ' + target
    corelations[key] = pearsonr(x1, x2)[0]


data_corelation = pd.DataFrame(corelations, index=["Value"]).T
# Out:
# (120, 1)

# %%
data_corelation.loc[data_corelation["Value"].abs().sort_values(ascending=False).index]
# Out:
#                                             Value
# EXT_SOURCE_2 vs TARGET                  -0.159030
# EXT_SOURCE_3 vs TARGET                  -0.119572
# DAYS_BIRTH vs TARGET                     0.078239
# EXT_SOURCE_1 vs TARGET                  -0.064698
# REGION_RATING_CLIENT_W_CITY vs TARGET    0.060893
# REGION_RATING_CLIENT vs TARGET           0.058899
# DAYS_LAST_PHONE_CHANGE vs TARGET         0.055217
# NAME_EDUCATION_TYPEcat vs TARGET         0.054699
# CODE_GENDERcat vs TARGET                 0.054692
# DAYS_ID_PUBLISH vs TARGET                0.051457
# REG_CITY_NOT_WORK_CITY vs TARGET         0.050994
# FLOORSMAX_AVG vs TARGET                 -0.049839
# FLOORSMAX_MEDI vs TARGET                -0.049720
# FLOORSMAX_MODE vs TARGET                -0.049458
# NAME_INCOME_TYPEcat vs TARGET            0.046829
# FLAG_EMP_PHONE vs TARGET                 0.045982
# DAYS_EMPLOYED vs TARGET                 -0.044932
# REG_CITY_NOT_LIVE_CITY vs TARGET         0.044395
# FLAG_DOCUMENT_3 vs TARGET                0.044346
# DAYS_REGISTRATION vs TARGET              0.041975
# TOTALAREA_MODE vs TARGET                -0.041037
# YEARS_BEGINEXPLUATATION_MEDI vs TARGET  -0.040983
# YEARS_BEGINEXPLUATATION_AVG vs TARGET   -0.040965
# OCCUPATION_TYPEcat vs TARGET             0.040945
# YEARS_BEGINEXPLUATATION_MODE vs TARGET  -0.040944
# LIVINGAREA_AVG vs TARGET                -0.040301
# LIVINGAREA_MEDI vs TARGET               -0.040123
# APARTMENTS_AVG vs TARGET                -0.039924
# APARTMENTS_MEDI vs TARGET               -0.039720
# AMT_GOODS_PRICE vs TARGET               -0.039565
# ...                                           ...
# FLAG_OWN_REALTYcat vs TARGET            -0.006148
# NONLIVINGAPARTMENTS_AVG vs TARGET       -0.005910
# AMT_REQ_CREDIT_BUREAU_QRT vs TARGET     -0.005833
# NONLIVINGAPARTMENTS_MEDI vs TARGET      -0.005650
# REG_REGION_NOT_LIVE_REGION vs TARGET     0.005576
# AMT_REQ_CREDIT_BUREAU_YEAR vs TARGET     0.005522
# FLAG_DOCUMENT_2 vs TARGET                0.005417
# NONLIVINGAPARTMENTS_MODE vs TARGET      -0.004859
# FLAG_DOCUMENT_9 vs TARGET               -0.004352
# FLAG_DOCUMENT_11 vs TARGET              -0.004229
# NAME_FAMILY_STATUScat vs TARGET         -0.004127
# WEEKDAY_APPR_PROCESS_STARTcat vs TARGET  0.004002
# AMT_INCOME_TOTAL vs TARGET              -0.003982
# FLAG_DOCUMENT_21 vs TARGET               0.003709
# FLAG_DOCUMENT_17 vs TARGET              -0.003378
# LIVE_REGION_NOT_WORK_REGION vs TARGET    0.002819
# FLAG_DOCUMENT_4 vs TARGET               -0.002672
# OWN_CAR_AGE vs TARGET                    0.002285
# FLAG_EMAIL vs TARGET                    -0.001758
# AMT_REQ_CREDIT_BUREAU_DAY vs TARGET      0.001701
# FLAG_DOCUMENT_7 vs TARGET               -0.001520
# FLAG_DOCUMENT_10 vs TARGET              -0.001414
# FLAG_DOCUMENT_19 vs TARGET              -0.001358
# AMT_REQ_CREDIT_BUREAU_WEEK vs TARGET    -0.001306
# FLAG_DOCUMENT_12 vs TARGET              -0.000756
# FLAG_MOBIL vs TARGET                     0.000534
# FLAG_CONT_MOBILE vs TARGET               0.000370
# FLAG_DOCUMENT_5 vs TARGET               -0.000316
# FLAG_DOCUMENT_20 vs TARGET               0.000215
# AMT_REQ_CREDIT_BUREAU_HOUR vs TARGET    -0.000074
#
# [120 rows x 1 columns]

# %%
def print_full(x):
    pd.set_option('display.max_rows', len(x))
    print(x)
    pd.reset_option('display.max_rows')

# %%
print_full(data_corelation.loc[data_corelation["Value"].abs().sort_values(ascending=False).index]
# Out:
#                                             Value
# EXT_SOURCE_2 vs TARGET                  -0.159030
# EXT_SOURCE_3 vs TARGET                  -0.119572
# DAYS_BIRTH vs TARGET                     0.078239
# EXT_SOURCE_1 vs TARGET                  -0.064698
# REGION_RATING_CLIENT_W_CITY vs TARGET    0.060893
# REGION_RATING_CLIENT vs TARGET           0.058899
# DAYS_LAST_PHONE_CHANGE vs TARGET         0.055217
# NAME_EDUCATION_TYPEcat vs TARGET         0.054699
# CODE_GENDERcat vs TARGET                 0.054692
# DAYS_ID_PUBLISH vs TARGET                0.051457
# REG_CITY_NOT_WORK_CITY vs TARGET         0.050994
# FLOORSMAX_AVG vs TARGET                 -0.049839
# FLOORSMAX_MEDI vs TARGET                -0.049720
# FLOORSMAX_MODE vs TARGET                -0.049458
# NAME_INCOME_TYPEcat vs TARGET            0.046829
# FLAG_EMP_PHONE vs TARGET                 0.045982
# DAYS_EMPLOYED vs TARGET                 -0.044932
# REG_CITY_NOT_LIVE_CITY vs TARGET         0.044395
# FLAG_DOCUMENT_3 vs TARGET                0.044346
# DAYS_REGISTRATION vs TARGET              0.041975
# TOTALAREA_MODE vs TARGET                -0.041037
# YEARS_BEGINEXPLUATATION_MEDI vs TARGET  -0.040983
# YEARS_BEGINEXPLUATATION_AVG vs TARGET   -0.040965
# OCCUPATION_TYPEcat vs TARGET             0.040945
# YEARS_BEGINEXPLUATATION_MODE vs TARGET  -0.040944
# LIVINGAREA_AVG vs TARGET                -0.040301
# LIVINGAREA_MEDI vs TARGET               -0.040123
# APARTMENTS_AVG vs TARGET                -0.039924
# APARTMENTS_MEDI vs TARGET               -0.039720
# AMT_GOODS_PRICE vs TARGET               -0.039565
# EMERGENCYSTATE_MODEcat vs TARGET        -0.039409
# LIVINGAREA_MODE vs TARGET               -0.038797
# APARTMENTS_MODE vs TARGET               -0.038522
# ENTRANCES_AVG vs TARGET                 -0.038402
# ENTRANCES_MEDI vs TARGET                -0.038273
# REGION_POPULATION_RELATIVE vs TARGET    -0.037227
# ENTRANCES_MODE vs TARGET                -0.037196
# HOUSETYPE_MODEcat vs TARGET             -0.036390
# ELEVATORS_AVG vs TARGET                 -0.035853
# ELEVATORS_MEDI vs TARGET                -0.035552
# WALLSMATERIAL_MODEcat vs TARGET         -0.034643
# NAME_HOUSING_TYPEcat vs TARGET           0.034489
# ELEVATORS_MODE vs TARGET                -0.034220
# FLOORSMIN_AVG vs TARGET                 -0.034177
# FLOORSMIN_MEDI vs TARGET                -0.034089
# FLOORSMIN_MODE vs TARGET                -0.033818
# BASEMENTAREA_AVG vs TARGET              -0.033759
# BASEMENTAREA_MEDI vs TARGET             -0.033428
# YEARS_BUILD_MEDI vs TARGET              -0.033074
# YEARS_BUILD_AVG vs TARGET               -0.033073
# YEARS_BUILD_MODE vs TARGET              -0.033025
# LIVE_CITY_NOT_WORK_CITY vs TARGET        0.032518
# DEF_30_CNT_SOCIAL_CIRCLE vs TARGET       0.032394
# BASEMENTAREA_MODE vs TARGET             -0.032131
# DEF_60_CNT_SOCIAL_CIRCLE vs TARGET       0.031401
# NAME_CONTRACT_TYPEcat vs TARGET         -0.030896
# ORGANIZATION_TYPEcat vs TARGET          -0.030765
# AMT_CREDIT vs TARGET                    -0.030369
# LIVINGAPARTMENTS_AVG vs TARGET          -0.029525
# LIVINGAPARTMENTS_MEDI vs TARGET         -0.029367
# FONDKAPREMONT_MODEcat vs TARGET         -0.028960
# LIVINGAPARTMENTS_MODE vs TARGET         -0.028829
# FLAG_DOCUMENT_6 vs TARGET               -0.028602
# FLAG_WORK_PHONE vs TARGET                0.028524
# HOUR_APPR_PROCESS_START vs TARGET       -0.024166
# FLAG_PHONE vs TARGET                    -0.023806
# LANDAREA_MEDI vs TARGET                 -0.023345
# LANDAREA_AVG vs TARGET                  -0.023152
# LANDAREA_MODE vs TARGET                 -0.022481
# FLAG_OWN_CARcat vs TARGET               -0.021851
# COMMONAREA_AVG vs TARGET                -0.020853
# COMMONAREA_MEDI vs TARGET               -0.020848
# COMMONAREA_MODE vs TARGET               -0.019617
# NONLIVINGAREA_AVG vs TARGET             -0.019446
# CNT_CHILDREN vs TARGET                   0.019187
# NONLIVINGAREA_MEDI vs TARGET            -0.019171
# NONLIVINGAREA_MODE vs TARGET            -0.018367
# AMT_REQ_CREDIT_BUREAU_MON vs TARGET     -0.014794
# AMT_ANNUITY vs TARGET                   -0.012794
# FLAG_DOCUMENT_16 vs TARGET              -0.011615
# FLAG_DOCUMENT_13 vs TARGET              -0.011583
# NAME_TYPE_SUITEcat vs TARGET             0.009693
# FLAG_DOCUMENT_14 vs TARGET              -0.009464
# OBS_30_CNT_SOCIAL_CIRCLE vs TARGET       0.009447
# OBS_60_CNT_SOCIAL_CIRCLE vs TARGET       0.009337
# CNT_FAM_MEMBERS vs TARGET                0.009312
# FLAG_DOCUMENT_8 vs TARGET               -0.008040
# FLAG_DOCUMENT_18 vs TARGET              -0.007952
# REG_REGION_NOT_WORK_REGION vs TARGET     0.006942
# FLAG_DOCUMENT_15 vs TARGET              -0.006536
# FLAG_OWN_REALTYcat vs TARGET            -0.006148
# NONLIVINGAPARTMENTS_AVG vs TARGET       -0.005910
# AMT_REQ_CREDIT_BUREAU_QRT vs TARGET     -0.005833
# NONLIVINGAPARTMENTS_MEDI vs TARGET      -0.005650
# REG_REGION_NOT_LIVE_REGION vs TARGET     0.005576
# AMT_REQ_CREDIT_BUREAU_YEAR vs TARGET     0.005522
# FLAG_DOCUMENT_2 vs TARGET                0.005417
# NONLIVINGAPARTMENTS_MODE vs TARGET      -0.004859
# FLAG_DOCUMENT_9 vs TARGET               -0.004352
# FLAG_DOCUMENT_11 vs TARGET              -0.004229
# NAME_FAMILY_STATUScat vs TARGET         -0.004127
# WEEKDAY_APPR_PROCESS_STARTcat vs TARGET  0.004002
# AMT_INCOME_TOTAL vs TARGET              -0.003982
# FLAG_DOCUMENT_21 vs TARGET               0.003709
# FLAG_DOCUMENT_17 vs TARGET              -0.003378
# LIVE_REGION_NOT_WORK_REGION vs TARGET    0.002819
# FLAG_DOCUMENT_4 vs TARGET               -0.002672
# OWN_CAR_AGE vs TARGET                    0.002285
# FLAG_EMAIL vs TARGET                    -0.001758
# AMT_REQ_CREDIT_BUREAU_DAY vs TARGET      0.001701
# FLAG_DOCUMENT_7 vs TARGET               -0.001520
# FLAG_DOCUMENT_10 vs TARGET              -0.001414
# FLAG_DOCUMENT_19 vs TARGET              -0.001358
# AMT_REQ_CREDIT_BUREAU_WEEK vs TARGET    -0.001306
# FLAG_DOCUMENT_12 vs TARGET              -0.000756
# FLAG_MOBIL vs TARGET                     0.000534
# FLAG_CONT_MOBILE vs TARGET               0.000370
# FLAG_DOCUMENT_5 vs TARGET               -0.000316
# FLAG_DOCUMENT_20 vs TARGET               0.000215
# AMT_REQ_CREDIT_BUREAU_HOUR vs TARGET    -0.000074

# %%
# Out:
# ['Value']
